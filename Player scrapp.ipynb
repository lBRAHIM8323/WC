# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = ["https://fbref.com/en/players/7a2e46a8/Alisson",
"https://fbref.com/en/players/c9e99e49/Dani-Alves",
"https://fbref.com/en/players/99127249/Antony",
"https://fbref.com/en/players/5fd5ed86/Gleison-Bremer",
"https://fbref.com/en/players/4d224fe8/Casemiro",
"https://fbref.com/en/players/94b2001f/Danilo",
"https://fbref.com/en/players/3bb7b8b4/Ederson",
"https://fbref.com/en/players/7f3b388c/Fabinho",
"https://fbref.com/en/players/b853e0ad/Fred",
"https://fbref.com/en/players/82518f62/Bruno-Guimaraes",
"https://fbref.com/en/players/b66315ae/Gabriel-Jesus",
"https://fbref.com/en/players/7111d552/Vinicius-Junior",
"https://fbref.com/en/players/d5f2f82b/Marquinhos",
"https://fbref.com/en/players/48a5a5d6/Martinelli",
"https://fbref.com/en/players/2784f898/Eder-Militao",
"https://fbref.com/en/players/69384e5d/Neymar",
"https://fbref.com/en/players/9b6f7fd5/Lucas-Paqueta",
"https://fbref.com/en/players/1ab6fad3/Pedro",
"https://fbref.com/en/players/3423f250/Raphinha",
"https://fbref.com/en/players/68fb50a2/Everton-Ribeiro",
"https://fbref.com/en/players/fa031b34/Richarlison",
"https://fbref.com/en/players/8f5e92a6/Rodrygo",
"https://fbref.com/en/players/0d82903c/Alex-Sandro",
"https://fbref.com/en/players/86e7deaf/Thiago-Silva",
"https://fbref.com/en/players/e73c9bb2/Alex-Telles",
"https://fbref.com/en/players/81be82e9/Weverton"]

# %%
len(url)
# Out:
# 26

# %%
for i in range (0,26):
    con = pd.read_html(url[i])
    print(con[0])
con[0].to_csv("Brazil_player_1.csv")
# Out:
#                          Statistic Per 90  Percentile
# 0                          PSxG-GA  +0.17        89.0
# 1                    Goals Against   0.88        91.0
# 2                  Save Percentage  73.0%        71.0
# 3                         PSxG/SoT   0.32        92.0
# 4            Save% (Penalty Kicks)  40.0%        81.0
# 5           Clean Sheet Percentage  42.9%        93.0
# 6                              NaN    NaN         NaN
# 7                          Touches  39.43        71.0
# 8                         Launch %  18.5%         4.0
# 9                       Goal Kicks   4.65         6.0
# 10       Avg. Length of Goal Kicks   33.5        18.0
# 11                             NaN    NaN         NaN
# 12               Crosses Stopped %   7.3%        81.0
# 13  Def. Actions Outside Pen. Area   1.96        93.0
# 14   Avg. Distance of Def. Actions   19.1        94.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.00        16.0
# 1           Non-Penalty xG   0.05        42.0
# 2              Shots Total   1.08        60.0
# 3                  Assists   0.33        99.0
# 4                      xAG   0.23        95.0
# 5               npxG + xAG   0.28        87.0
# 6    Shot-Creating Actions   5.25        99.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  57.75        79.0
# 9        Pass Completion %  76.3%        22.0
# 10      Progressive Passes   6.00        95.0
# 11      Dribbles Completed   0.67        52.0
# 12       Touches (Att Pen)   0.67        39.0
# 13  Progressive Passes Rec   2.17        70.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.58        27.0
# 16           Interceptions   0.58         7.0
# 17                  Blocks   0.33         1.0
# 18              Clearances   0.17         1.0
# 19             Aerials won   0.33         8.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.27        55.0
# 1           Non-Penalty xG   0.24        55.0
# 2              Shots Total   3.13        90.0
# 3                  Assists   0.00         1.0
# 4                      xAG   0.09         1.0
# 5               npxG + xAG   0.34        17.0
# 6    Shot-Creating Actions   3.58        36.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  44.96        60.0
# 9        Pass Completion %  78.1%        55.0
# 10      Progressive Passes   2.86        46.0
# 11      Dribbles Completed   1.52        56.0
# 12       Touches (Att Pen)   3.49        42.0
# 13  Progressive Passes Rec   5.99        64.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.52        72.0
# 16           Interceptions   0.36        25.0
# 17                  Blocks   1.25        85.0
# 18              Clearances   0.18        16.0
# 19             Aerials won   0.63        65.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.06        67.0
# 1           Non-Penalty xG   0.10        94.0
# 2              Shots Total   0.79        88.0
# 3                  Assists   0.00        31.0
# 4                      xAG   0.01        22.0
# 5               npxG + xAG   0.11        80.0
# 6    Shot-Creating Actions   0.70        48.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  50.38        41.0
# 9        Pass Completion %  86.2%        61.0
# 10      Progressive Passes   1.40         8.0
# 11      Dribbles Completed   0.34        79.0
# 12       Touches (Att Pen)   1.19        86.0
# 13  Progressive Passes Rec   0.18        55.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.07        21.0
# 16           Interceptions   2.38        98.0
# 17                  Blocks   1.77        93.0
# 18              Clearances   4.06        64.0
# 19             Aerials won   3.11        92.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.06        48.0
# 1           Non-Penalty xG   0.10        63.0
# 2              Shots Total   1.42        75.0
# 3                  Assists   0.03        26.0
# 4                      xAG   0.09        53.0
# 5               npxG + xAG   0.19        54.0
# 6    Shot-Creating Actions   2.50        57.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  69.09        91.0
# 9        Pass Completion %  82.5%        54.0
# 10      Progressive Passes   5.12        84.0
# 11      Dribbles Completed   0.68        46.0
# 12       Touches (Att Pen)   1.23        54.0
# 13  Progressive Passes Rec   1.14        35.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   3.24        95.0
# 16           Interceptions   1.67        89.0
# 17                  Blocks   2.07        99.0
# 18              Clearances   2.31        97.0
# 19             Aerials won   3.89        99.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.03        48.0
# 1           Non-Penalty xG   0.05        60.0
# 2              Shots Total   0.63        48.0
# 3                  Assists   0.09        54.0
# 4                      xAG   0.11        58.0
# 5               npxG + xAG   0.16        55.0
# 6    Shot-Creating Actions   1.85        39.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  63.91        83.0
# 9        Pass Completion %  84.6%        89.0
# 10      Progressive Passes   3.54        70.0
# 11      Dribbles Completed   0.28        13.0
# 12       Touches (Att Pen)   1.07        41.0
# 13  Progressive Passes Rec   0.91         8.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.91        44.0
# 16           Interceptions   1.72        93.0
# 17                  Blocks   0.91        22.0
# 18              Clearances   2.57        80.0
# 19             Aerials won   1.41        78.0
#                          Statistic Per 90  Percentile
# 0                          PSxG-GA  -0.07        35.0
# 1                    Goals Against   0.81        95.0
# 2                  Save Percentage  69.1%        36.0
# 3                         PSxG/SoT   0.27        37.0
# 4            Save% (Penalty Kicks)   0.0%        24.0
# 5           Clean Sheet Percentage  54.3%        99.0
# 6                              NaN    NaN         NaN
# 7                          Touches  34.60        37.0
# 8                         Launch %  18.1%         3.0
# 9                       Goal Kicks   4.15         2.0
# 10       Avg. Length of Goal Kicks   30.4        14.0
# 11                             NaN    NaN         NaN
# 12               Crosses Stopped %   6.2%        64.0
# 13  Def. Actions Outside Pen. Area   1.35        66.0
# 14   Avg. Distance of Def. Actions   19.0        93.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.08        56.0
# 1           Non-Penalty xG   0.06        37.0
# 2              Shots Total   0.56        14.0
# 3                  Assists   0.00        11.0
# 4                      xAG   0.05        23.0
# 5               npxG + xAG   0.11        24.0
# 6    Shot-Creating Actions   2.26        46.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  63.02        82.0
# 9        Pass Completion %  87.4%        85.0
# 10      Progressive Passes   3.73        54.0
# 11      Dribbles Completed   0.35        14.0
# 12       Touches (Att Pen)   0.67        26.0
# 13  Progressive Passes Rec   1.12        34.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   2.10        53.0
# 16           Interceptions   1.44        78.0
# 17                  Blocks   1.39        67.0
# 18              Clearances   0.91        41.0
# 19             Aerials won   1.44        78.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.15        85.0
# 1           Non-Penalty xG   0.11        71.0
# 2              Shots Total   1.50        78.0
# 3                  Assists   0.15        83.0
# 4                      xAG   0.13        71.0
# 5               npxG + xAG   0.25        74.0
# 6    Shot-Creating Actions   3.56        90.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  61.10        78.0
# 9        Pass Completion %  83.8%        64.0
# 10      Progressive Passes   4.44        71.0
# 11      Dribbles Completed   1.08        71.0
# 12       Touches (Att Pen)   1.60        68.0
# 13  Progressive Passes Rec   2.63        76.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   2.74        83.0
# 16           Interceptions   1.50        81.0
# 17                  Blocks   1.70        90.0
# 18              Clearances   0.72        27.0
# 19             Aerials won   0.57        29.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.29        99.0
# 1           Non-Penalty xG   0.14        81.0
# 2              Shots Total   1.25        67.0
# 3                  Assists   0.15        81.0
# 4                      xAG   0.16        81.0
# 5               npxG + xAG   0.30        84.0
# 6    Shot-Creating Actions   3.39        85.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  55.73        66.0
# 9        Pass Completion %  83.6%        64.0
# 10      Progressive Passes   4.79        78.0
# 11      Dribbles Completed   1.51        89.0
# 12       Touches (Att Pen)   1.21        52.0
# 13  Progressive Passes Rec   1.07        34.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   3.50        97.0
# 16           Interceptions   1.14        57.0
# 17                  Blocks   1.73        91.0
# 18              Clearances   0.81        32.0
# 19             Aerials won   0.44        17.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.38        57.0
# 1           Non-Penalty xG   0.52        88.0
# 2              Shots Total   3.33        85.0
# 3                  Assists   0.27        88.0
# 4                      xAG   0.25        94.0
# 5               npxG + xAG   0.77        94.0
# 6    Shot-Creating Actions   4.23        95.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  30.86        85.0
# 9        Pass Completion %  82.0%        96.0
# 10      Progressive Passes   1.72        70.0
# 11      Dribbles Completed   2.41        96.0
# 12       Touches (Att Pen)   8.80        98.0
# 13  Progressive Passes Rec   7.94        89.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.13        90.0
# 16           Interceptions   0.58        97.0
# 17                  Blocks   1.07        90.0
# 18              Clearances   0.48        29.0
# 19             Aerials won   1.41        39.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.45        89.0
# 1           Non-Penalty xG   0.48        98.0
# 2              Shots Total   2.63        68.0
# 3                  Assists   0.36        87.0
# 4                      xAG   0.28        80.0
# 5               npxG + xAG   0.76        94.0
# 6    Shot-Creating Actions   5.01        88.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  38.92        46.0
# 9        Pass Completion %  81.2%        76.0
# 10      Progressive Passes   2.22        22.0
# 11      Dribbles Completed   2.77        92.0
# 12       Touches (Att Pen)   7.12        99.0
# 13  Progressive Passes Rec   8.76        97.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.34        64.0
# 16           Interceptions   0.24        11.0
# 17                  Blocks   0.64        22.0
# 18              Clearances   0.12         8.0
# 19             Aerials won   0.05         3.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.08        77.0
# 1           Non-Penalty xG   0.09        88.0
# 2              Shots Total   0.58        67.0
# 3                  Assists   0.00        31.0
# 4                      xAG   0.01        24.0
# 5               npxG + xAG   0.10        71.0
# 6    Shot-Creating Actions   0.55        29.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  68.86        86.0
# 9        Pass Completion %  94.0%        99.0
# 10      Progressive Passes   1.90        26.0
# 11      Dribbles Completed   0.10        25.0
# 12       Touches (Att Pen)   1.08        77.0
# 13  Progressive Passes Rec   0.28        72.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   0.98        14.0
# 16           Interceptions   0.68         5.0
# 17                  Blocks   1.10        42.0
# 18              Clearances   2.81        22.0
# 19             Aerials won   1.13         7.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.27        56.0
# 1           Non-Penalty xG   0.30        70.0
# 2              Shots Total   2.51        62.0
# 3                  Assists   0.21        56.0
# 4                      xAG   0.24        64.0
# 5               npxG + xAG   0.54        68.0
# 6    Shot-Creating Actions   3.96        51.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  34.21        28.0
# 9        Pass Completion %  74.6%        33.0
# 10      Progressive Passes   2.09        17.0
# 11      Dribbles Completed   2.18        83.0
# 12       Touches (Att Pen)   6.10        88.0
# 13  Progressive Passes Rec   6.38        74.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.06        33.0
# 16           Interceptions   0.73        80.0
# 17                  Blocks   1.21        83.0
# 18              Clearances   0.73        83.0
# 19             Aerials won   0.66        68.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.11        91.0
# 1           Non-Penalty xG   0.08        81.0
# 2              Shots Total   0.94        95.0
# 3                  Assists   0.03        63.0
# 4                      xAG   0.02        57.0
# 5               npxG + xAG   0.10        75.0
# 6    Shot-Creating Actions   0.87        69.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  58.95        67.0
# 9        Pass Completion %  87.2%        68.0
# 10      Progressive Passes   1.71        19.0
# 11      Dribbles Completed   0.39        86.0
# 12       Touches (Att Pen)   1.18        85.0
# 13  Progressive Passes Rec   0.34        79.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.57        61.0
# 16           Interceptions   1.36        51.0
# 17                  Blocks   1.57        86.0
# 18              Clearances   3.10        29.0
# 19             Aerials won   2.34        66.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.64        99.0
# 1           Non-Penalty xG   0.42        87.0
# 2              Shots Total   2.67        70.0
# 3                  Assists   0.54        97.0
# 4                      xAG   0.53        99.0
# 5               npxG + xAG   0.94        99.0
# 6    Shot-Creating Actions   6.79        99.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  69.11        99.0
# 9        Pass Completion %  80.9%        74.0
# 10      Progressive Passes   6.56        99.0
# 11      Dribbles Completed   2.06        79.0
# 12       Touches (Att Pen)   4.80        72.0
# 13  Progressive Passes Rec   7.84        88.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.28        61.0
# 16           Interceptions   0.24        10.0
# 17                  Blocks   0.41         7.0
# 18              Clearances   0.07         3.0
# 19             Aerials won   0.10         7.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.14        19.0
# 1           Non-Penalty xG   0.27        66.0
# 2              Shots Total   2.64        69.0
# 3                  Assists   0.17        43.0
# 4                      xAG   0.22        51.0
# 5               npxG + xAG   0.48        55.0
# 6    Shot-Creating Actions   3.64        42.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  56.00        92.0
# 9        Pass Completion %  80.2%        67.0
# 10      Progressive Passes   5.20        95.0
# 11      Dribbles Completed   1.98        77.0
# 12       Touches (Att Pen)   2.91        26.0
# 13  Progressive Passes Rec   6.31        70.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   2.19        98.0
# 16           Interceptions   0.42        32.0
# 17                  Blocks   1.49        95.0
# 18              Clearances   0.90        95.0
# 19             Aerials won   1.63        92.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   1.10        99.0
# 1           Non-Penalty xG   0.82        99.0
# 2              Shots Total   4.01        94.0
# 3                  Assists   0.24        91.0
# 4                      xAG   0.25        98.0
# 5               npxG + xAG   1.07        99.0
# 6    Shot-Creating Actions   2.72        68.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  16.01        14.0
# 9        Pass Completion %  74.9%        83.0
# 10      Progressive Passes   1.29        53.0
# 11      Dribbles Completed   0.86        58.0
# 12       Touches (Att Pen)   6.50        92.0
# 13  Progressive Passes Rec   6.40        80.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   0.48        32.0
# 16           Interceptions   0.24        68.0
# 17                  Blocks   0.67        65.0
# 18              Clearances   0.53        27.0
# 19             Aerials won   1.67        39.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.13        17.0
# 1           Non-Penalty xG   0.27        67.0
# 2              Shots Total   2.74        74.0
# 3                  Assists   0.20        53.0
# 4                      xAG   0.30        89.0
# 5               npxG + xAG   0.58        74.0
# 6    Shot-Creating Actions   4.41        69.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  45.13        61.0
# 9        Pass Completion %  67.0%         6.0
# 10      Progressive Passes   4.45        86.0
# 11      Dribbles Completed   1.44        48.0
# 12       Touches (Att Pen)   4.98        77.0
# 13  Progressive Passes Rec   6.45        75.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.60        78.0
# 16           Interceptions   0.77        82.0
# 17                  Blocks   1.54        97.0
# 18              Clearances   0.77        87.0
# 19             Aerials won   0.57        57.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.20        93.0
# 1           Non-Penalty xG   0.17        94.0
# 2              Shots Total   1.26        71.0
# 3                  Assists   0.20        89.0
# 4                      xAG   0.26        98.0
# 5               npxG + xAG   0.42        98.0
# 6    Shot-Creating Actions   4.33        96.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  56.80        78.0
# 9        Pass Completion %  80.9%        47.0
# 10      Progressive Passes   5.72        92.0
# 11      Dribbles Completed   2.08        97.0
# 12       Touches (Att Pen)   2.35        92.0
# 13  Progressive Passes Rec   5.52        99.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   2.41        74.0
# 16           Interceptions   0.93        33.0
# 17                  Blocks   1.16        58.0
# 18              Clearances   0.26         2.0
# 19             Aerials won   0.63        28.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.22        19.0
# 1           Non-Penalty xG   0.31        32.0
# 2              Shots Total   2.71        57.0
# 3                  Assists   0.18        69.0
# 4                      xAG   0.15        64.0
# 5               npxG + xAG   0.46        39.0
# 6    Shot-Creating Actions   2.82        72.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  23.16        56.0
# 9        Pass Completion %  63.6%        20.0
# 10      Progressive Passes   1.39        57.0
# 11      Dribbles Completed   1.39        83.0
# 12       Touches (Att Pen)   5.13        64.0
# 13  Progressive Passes Rec   4.84        27.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.47        96.0
# 16           Interceptions   0.51        96.0
# 17                  Blocks   1.50        99.0
# 18              Clearances   1.17        88.0
# 19             Aerials won   2.09        60.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.39        79.0
# 1           Non-Penalty xG   0.38        84.0
# 2              Shots Total   3.09        88.0
# 3                  Assists   0.28        75.0
# 4                      xAG   0.26        72.0
# 5               npxG + xAG   0.64        86.0
# 6    Shot-Creating Actions   4.70        79.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  38.18        43.0
# 9        Pass Completion %  83.8%        91.0
# 10      Progressive Passes   1.58         7.0
# 11      Dribbles Completed   1.72        67.0
# 12       Touches (Att Pen)   6.60        94.0
# 13  Progressive Passes Rec   7.23        86.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.16        45.0
# 16           Interceptions   0.60        67.0
# 17                  Blocks   1.16        80.0
# 18              Clearances   0.28        31.0
# 19             Aerials won   0.77        72.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.00        21.0
# 1           Non-Penalty xG   0.01        12.0
# 2              Shots Total   0.32        16.0
# 3                  Assists   0.09        53.0
# 4                      xAG   0.04         8.0
# 5               npxG + xAG   0.05         4.0
# 6    Shot-Creating Actions   1.63        22.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  59.80        75.0
# 9        Pass Completion %  86.0%        93.0
# 10      Progressive Passes   3.59        72.0
# 11      Dribbles Completed   0.77        59.0
# 12       Touches (Att Pen)   0.86        27.0
# 13  Progressive Passes Rec   1.00         9.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.54        20.0
# 16           Interceptions   1.50        86.0
# 17                  Blocks   1.23        63.0
# 18              Clearances   2.09        56.0
# 19             Aerials won   1.63        85.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.03        36.0
# 1           Non-Penalty xG   0.05        47.0
# 2              Shots Total   0.59        68.0
# 3                  Assists   0.05        84.0
# 4                      xAG   0.01        31.0
# 5               npxG + xAG   0.06        40.0
# 6    Shot-Creating Actions   0.97        78.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  84.86        98.0
# 9        Pass Completion %  92.1%        96.0
# 10      Progressive Passes   3.97        93.0
# 11      Dribbles Completed   0.15        43.0
# 12       Touches (Att Pen)   0.74        46.0
# 13  Progressive Passes Rec   0.08        23.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.20        34.0
# 16           Interceptions   1.50        64.0
# 17                  Blocks   1.65        90.0
# 18              Clearances   3.38        44.0
# 19             Aerials won   1.91        43.0
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.00        21.0
# 1           Non-Penalty xG   0.02        26.0
# 2              Shots Total   0.55        43.0
# 3                  Assists   0.24        90.0
# 4                      xAG   0.13        69.0
# 5               npxG + xAG   0.15        52.0
# 6    Shot-Creating Actions   2.74        77.0
# 7                      NaN    NaN         NaN
# 8         Passes Attempted  60.78        77.0
# 9        Pass Completion %  75.1%        39.0
# 10      Progressive Passes   2.22        19.0
# 11      Dribbles Completed   0.86        67.0
# 12       Touches (Att Pen)   0.99        37.0
# 13  Progressive Passes Rec   2.57        68.0
# 14                     NaN    NaN         NaN
# 15                 Tackles   1.85        38.0
# 16           Interceptions   1.27        68.0
# 17                  Blocks   0.96        31.0
# 18              Clearances   2.09        55.0
# 19             Aerials won   1.68        88.0
#                          Statistic Per 90  Percentile
# 0                          PSxG-GA  +0.21        87.0
# 1                    Goals Against   0.70        99.0
# 2                  Save Percentage  80.4%        94.0
# 3                         PSxG/SoT   0.25        20.0
# 4            Save% (Penalty Kicks)   0.0%        27.0
# 5           Clean Sheet Percentage  47.8%        95.0
# 6                              NaN    NaN         NaN
# 7                          Touches  32.83        38.0
# 8                         Launch %  36.1%        33.0
# 9                       Goal Kicks   7.00        20.0
# 10       Avg. Length of Goal Kicks   35.1        11.0
# 11                             NaN    NaN         NaN
# 12               Crosses Stopped %   6.5%        67.0
# 13  Def. Actions Outside Pen. Area   0.89        52.0
# 14   Avg. Distance of Def. Actions   14.9        70.0

# %%
con[0].to_csv("Brazil_player_2.csv")
